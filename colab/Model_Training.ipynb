# %% [markdown]
# <a href="https://colab.research.google.com/github/dgrifka/nfl_motion_coverage_overlap/blob/main/Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Model Preparation**

# %% [markdown]
# We're going to save and train a neural network that predicts future player positions (trajectories) based on various game situations. The code for this notebook can be found at https://github.com/dgrifka/nfl_motion_coverage_overlap.
#
# First, we must import the functions necessary.

# %%
# !git clone https://github.com/dgrifka/nfl_motion_coverage_overlap.git

import os

# Change this to the path of your repository
repo_path = '/content/nfl_motion_coverage_overlap'
os.chdir(repo_path)

# Import the necessary functions
# %run setup.py
# Out:
# Cloning into 'nfl_motion_coverage_overlap'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 45 (delta 12), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 35.97 MiB | 32.88 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %% [markdown]
# You must have the "players", "games", "plays", "player_play", and "tracking_week" CSV files in your Google Drive. Another way to do this would be to upload the files manually to Colab.
#
# If the files are in your Google Drive, then go ahead and mount your drive below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Next, we're going to import and clean all the necessary data for the model.
#
# Note: We're giong to use Polars vs Pandas simply because it's faster.

# %%
players = read_nfl_csv('players')
players.head()
# Out:
# shape: (5, 7)
# ┌───────┬────────┬────────┬────────────┬────────────────┬──────────┬────────────────┐
# │ nflId ┆ height ┆ weight ┆ birthDate  ┆ collegeName    ┆ position ┆ displayName    │
# │ ---   ┆ ---    ┆ ---    ┆ ---        ┆ ---            ┆ ---      ┆ ---            │
# │ i64   ┆ str    ┆ i64    ┆ str        ┆ str            ┆ str      ┆ str            │
# ╞═══════╪════════╪════════╪════════════╪════════════════╪══════════╪════════════════╡
# │ 25511 ┆ 6-4    ┆ 225    ┆ 1977-08-03 ┆ Michigan       ┆ QB       ┆ Tom Brady      │
# │ 29550 ┆ 6-4    ┆ 328    ┆ 1982-01-22 ┆ Arkansas       ┆ T        ┆ Jason Peters   │
# │ 29851 ┆ 6-2    ┆ 225    ┆ 1983-12-02 ┆ California     ┆ QB       ┆ Aaron Rodgers  │
# │ 30842 ┆ 6-6    ┆ 267    ┆ 1984-05-19 ┆ UCLA           ┆ TE       ┆ Marcedes Lewis │
# │ 33084 ┆ 6-4    ┆ 217    ┆ 1985-05-17 ┆ Boston College ┆ QB       ┆ Matt Ryan      │
# └───────┴────────┴────────┴────────────┴────────────────┴──────────┴────────────────┘

# %%
games = read_nfl_csv('games')
games.head()
# Out:
# shape: (5, 9)
# ┌────────────┬────────┬──────┬───────────┬───┬─────────────┬─────────────┬────────────┬────────────┐
# │ gameId     ┆ season ┆ week ┆ gameDate  ┆ … ┆ homeTeamAbb ┆ visitorTeam ┆ homeFinalS ┆ visitorFin │
# │ ---        ┆ ---    ┆ ---  ┆ ---       ┆   ┆ r           ┆ Abbr        ┆ core       ┆ alScore    │
# │ i64        ┆ i64    ┆ i64  ┆ str       ┆   ┆ ---         ┆ ---         ┆ ---        ┆ ---        │
# │            ┆        ┆      ┆           ┆   ┆ str         ┆ str         ┆ i64        ┆ i64        │
# ╞════════════╪════════╪══════╪═══════════╪═══╪═════════════╪═════════════╪════════════╪════════════╡
# │ 2022090800 ┆ 2022   ┆ 1    ┆ 9/8/2022  ┆ … ┆ LA          ┆ BUF         ┆ 10         ┆ 31         │
# │ 2022091100 ┆ 2022   ┆ 1    ┆ 9/11/2022 ┆ … ┆ ATL         ┆ NO          ┆ 26         ┆ 27         │
# │ 2022091101 ┆ 2022   ┆ 1    ┆ 9/11/2022 ┆ … ┆ CAR         ┆ CLE         ┆ 24         ┆ 26         │
# │ 2022091102 ┆ 2022   ┆ 1    ┆ 9/11/2022 ┆ … ┆ CHI         ┆ SF          ┆ 19         ┆ 10         │
# │ 2022091103 ┆ 2022   ┆ 1    ┆ 9/11/2022 ┆ … ┆ CIN         ┆ PIT         ┆ 20         ┆ 23         │
# └────────────┴────────┴──────┴───────────┴───┴─────────────┴─────────────┴────────────┴────────────┘

# %%
plays_raw = read_nfl_csv('plays')
# Add team names and features, such as offense score differential
plays = process_nfl_plays(plays_raw, games)
plays.head()
# Out:
# shape: (5, 55)
# ┌────────────┬────────┬────────────┬─────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ gameId     ┆ playId ┆ playDescri ┆ quarter ┆ … ┆ visitorTea ┆ offense_sc ┆ game_time ┆ quarter_m │
# │ ---        ┆ ---    ┆ ption      ┆ ---     ┆   ┆ mAbbr      ┆ ore_diff   ┆ _left_min ┆ ins_left  │
# │ i64        ┆ i64    ┆ ---        ┆ i64     ┆   ┆ ---        ┆ ---        ┆ s         ┆ ---       │
# │            ┆        ┆ str        ┆         ┆   ┆ str        ┆ i64        ┆ ---       ┆ f64       │
# │            ┆        ┆            ┆         ┆   ┆            ┆            ┆ f64       ┆           │
# ╞════════════╪════════╪════════════╪═════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 2022102302 ┆ 2655   ┆ (1:54)     ┆ 3       ┆ … ┆ ATL        ┆ 18         ┆ 16.9      ┆ 1.9       │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ J.Burrow   ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass…      ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022091809 ┆ 3698   ┆ (2:13)     ┆ 4       ┆ … ┆ CIN        ┆ 0          ┆ 2.216667  ┆ 2.216667  │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ J.Burrow   ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass…      ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022103004 ┆ 3146   ┆ (2:00)     ┆ 4       ┆ … ┆ TEN        ┆ -14        ┆ 2.0       ┆ 2.0       │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ D.Mills    ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass …     ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022110610 ┆ 348    ┆ (9:28)     ┆ 1       ┆ … ┆ TEN        ┆ 0          ┆ 54.466667 ┆ 9.466667  │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ P.Mahomes  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pas…       ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022102700 ┆ 2799   ┆ (2:16)     ┆ 3       ┆ … ┆ BAL        ┆ 0          ┆ 17.266667 ┆ 2.266667  │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ L.Jackson  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ up …       ┆         ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────┴────────────┴─────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
player_play = read_nfl_csv('player_play')
player_play.head()
# Out:
# shape: (5, 50)
# ┌────────────┬────────┬───────┬──────────┬───┬─────────────┬─────────────┬────────────┬────────────┐
# │ gameId     ┆ playId ┆ nflId ┆ teamAbbr ┆ … ┆ timeToPress ┆ pff_defensi ┆ pff_primar ┆ pff_second │
# │ ---        ┆ ---    ┆ ---   ┆ ---      ┆   ┆ ureAllowedA ┆ veCoverageA ┆ yDefensive ┆ aryDefensi │
# │ i64        ┆ i64    ┆ i64   ┆ str      ┆   ┆ sBlocker    ┆ ssignmen…   ┆ CoverageMa ┆ veCoverage │
# │            ┆        ┆       ┆          ┆   ┆ ---         ┆ ---         ┆ …          ┆ …          │
# │            ┆        ┆       ┆          ┆   ┆ f64         ┆ str         ┆ ---        ┆ ---        │
# │            ┆        ┆       ┆          ┆   ┆             ┆             ┆ i64        ┆ i64        │
# ╞════════════╪════════╪═══════╪══════════╪═══╪═════════════╪═════════════╪════════════╪════════════╡
# │ 2022090800 ┆ 56     ┆ 35472 ┆ BUF      ┆ … ┆ null        ┆ null        ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ 42392 ┆ BUF      ┆ … ┆ null        ┆ null        ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ 42489 ┆ BUF      ┆ … ┆ null        ┆ null        ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ 44875 ┆ BUF      ┆ … ┆ null        ┆ null        ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ 44985 ┆ BUF      ┆ … ┆ null        ┆ null        ┆ null       ┆ null       │
# └────────────┴────────┴───────┴──────────┴───┴─────────────┴─────────────┴────────────┴────────────┘

# %%
# For post-snap data
post_snap = process_tracking_data(
    tracking_path=google_drive_path,
    snap_type="post",
    weeks=range(1, 10)
)

post_snap.head()
# Out:
# shape: (5, 18)
# ┌────────────┬────────┬───────┬─────────────┬───┬──────┬──────┬──────┬───────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName ┆ … ┆ dis  ┆ o    ┆ dir  ┆ event │
# │ ---        ┆ ---    ┆ ---   ┆ ---         ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---   │
# │ i64        ┆ i64    ┆ i64   ┆ str         ┆   ┆ f64  ┆ f64  ┆ f64  ┆ str   │
# ╞════════════╪════════╪═══════╪═════════════╪═══╪══════╪══════╪══════╪═══════╡
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ 0.0  ┆ null ┆ null ┆ null  │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ 1.53 ┆ null ┆ null ┆ null  │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ 0.81 ┆ null ┆ null ┆ null  │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ 0.71 ┆ null ┆ null ┆ null  │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ 0.69 ┆ null ┆ null ┆ null  │
# └────────────┴────────┴───────┴─────────────┴───┴──────┴──────┴──────┴───────┘

# %% [markdown]
# Now that we have the data loaded, we can calculate the average time to throw when a QB drops back.

# %%
mean_ttt = calculate_mean_ttt(post_snap)
print(f"Mean time to throw: {mean_ttt} seconds")
# Out:
# Mean time to throw: 2.64706561922366 seconds

# %%
# For post-snap data
post_snap_total = merge_tracking_data(post_snap, plays, players, add_team_column)
post_snap_total.head()
# Out:
# shape: (5, 31)
# ┌────────────┬────────┬───────┬─────────────┬───┬───────────────┬─────────────┬──────────┬─────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName ┆ … ┆ pff_passCover ┆ pff_manZone ┆ position ┆ team    │
# │ ---        ┆ ---    ┆ ---   ┆ ---         ┆   ┆ age           ┆ ---         ┆ ---      ┆ ---     │
# │ i64        ┆ i64    ┆ i64   ┆ str         ┆   ┆ ---           ┆ str         ┆ str      ┆ str     │
# │            ┆        ┆       ┆             ┆   ┆ str           ┆             ┆          ┆         │
# ╞════════════╪════════╪═══════╪═════════════╪═══╪═══════════════╪═════════════╪══════════╪═════════╡
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ Cover 6-Left  ┆ Zone        ┆ null     ┆ unknown │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ Cover 6-Left  ┆ Zone        ┆ null     ┆ unknown │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ Cover 6-Left  ┆ Zone        ┆ null     ┆ unknown │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ Cover 6-Left  ┆ Zone        ┆ null     ┆ unknown │
# │ 2022090800 ┆ 56     ┆ null  ┆ football    ┆ … ┆ Cover 6-Left  ┆ Zone        ┆ null     ┆ unknown │
# └────────────┴────────┴───────┴─────────────┴───┴───────────────┴─────────────┴──────────┴─────────┘

# %%
# Normalize x and y values, so that all plays are going left to right
post_snap_total_normalized = normalize_direction(post_snap_total)
post_snap_total_normalized.head()
# Out:
# shape: (5, 35)
# ┌────────────┬────────┬───────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayNam ┆ … ┆ x_normaliz ┆ y_normaliz ┆ o_normaliz ┆ dir_normal │
# │ ---        ┆ ---    ┆ ---   ┆ e          ┆   ┆ ed         ┆ ed         ┆ ed         ┆ ized       │
# │ i64        ┆ i64    ┆ i64   ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │            ┆        ┆       ┆ str        ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪════════╪═══════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2022090800 ┆ 56     ┆ null  ┆ football   ┆ … ┆ 34.839996  ┆ 29.690001  ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ null  ┆ football   ┆ … ┆ 33.389999  ┆ 30.15      ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ null  ┆ football   ┆ … ┆ 32.580002  ┆ 30.15      ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ null  ┆ football   ┆ … ┆ 31.870003  ┆ 30.15      ┆ null       ┆ null       │
# │ 2022090800 ┆ 56     ┆ null  ┆ football   ┆ … ┆ 31.18      ┆ 30.16      ┆ null       ┆ null       │
# └────────────┴────────┴───────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
# Only frames before mean time to throw
passing_play_shortened = calculate_shortened_passing_plays(
    post_snap_total_normalized,
    mean_ttt
)
passing_play_shortened.head()
# Out:
# shape: (5, 37)
# ┌────────────┬────────┬───────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayNam ┆ … ┆ o_normaliz ┆ dir_normal ┆ start_fram ┆ time_elaps │
# │ ---        ┆ ---    ┆ ---   ┆ e          ┆   ┆ ed         ┆ ized       ┆ e          ┆ ed         │
# │ i64        ┆ i64    ┆ i64   ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │            ┆        ┆       ┆ str        ┆   ┆ f64        ┆ f64        ┆ i64        ┆ f64        │
# ╞════════════╪════════╪═══════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2022090800 ┆ 56     ┆ 35472 ┆ Rodger     ┆ … ┆ 83.9       ┆ 238.97     ┆ 147        ┆ 0.0        │
# │            ┆        ┆       ┆ Saffold    ┆   ┆            ┆            ┆            ┆            │
# │ 2022090800 ┆ 56     ┆ 44985 ┆ Isaiah     ┆ … ┆ 82.03      ┆ 333.45     ┆ 147        ┆ 0.0        │
# │            ┆        ┆       ┆ McKenzie   ┆   ┆            ┆            ┆            ┆            │
# │ 2022090800 ┆ 56     ┆ 42392 ┆ Mitch      ┆ … ┆ 79.74      ┆ 274.98     ┆ 147        ┆ 0.0        │
# │            ┆        ┆       ┆ Morse      ┆   ┆            ┆            ┆            ┆            │
# │ 2022090800 ┆ 56     ┆ 42489 ┆ Stefon     ┆ … ┆ 99.77      ┆ 107.77     ┆ 147        ┆ 0.0        │
# │            ┆        ┆       ┆ Diggs      ┆   ┆            ┆            ┆            ┆            │
# │ 2022090800 ┆ 56     ┆ 53522 ┆ Spencer    ┆ … ┆ 108.54     ┆ 250.91     ┆ 147        ┆ 0.0        │
# │            ┆        ┆       ┆ Brown      ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────┴───────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# Then, we want to create a dataframe with the football location at the start of the play. This is implemented in a feature, but also for the visualization.

# %%
ball_df = get_initial_ball_position(passing_play_shortened)
ball_df.head()
# Out:
# shape: (5, 4)
# ┌────────────┬────────┬──────────────┬──────────────┐
# │ gameId     ┆ playId ┆ x_normalized ┆ y_normalized │
# │ ---        ┆ ---    ┆ ---          ┆ ---          │
# │ i64        ┆ i64    ┆ f64          ┆ f64          │
# ╞════════════╪════════╪══════════════╪══════════════╡
# │ 2022103001 ┆ 3700   ┆ 34.48        ┆ 24.049999    │
# │ 2022103006 ┆ 3519   ┆ 63.82        ┆ 24.48        │
# │ 2022110300 ┆ 2580   ┆ 41.709999    ┆ 23.75        │
# │ 2022100902 ┆ 3994   ┆ 55.300003    ┆ 25.709999    │
# │ 2022102302 ┆ 970    ┆ 76.089996    ┆ 23.99        │
# └────────────┴────────┴──────────────┴──────────────┘

# %%
# If you'd only like to train on a few games, then reduce the number below
n_games = 1000
# Get unique game IDs
game_ids = passing_play_shortened.select('gameId').unique().head(n_games)

# %%
# Get defensive and offensive players
def_df = filter_players_by_position(passing_play_shortened, game_ids, 'defense')
off_df = filter_players_by_position(passing_play_shortened, game_ids, 'offense')

# %%
# Add distance_from_football feature to both dataframes
def_df_with_distance = add_distance_from_football(def_df, ball_df)
off_df_with_distance = add_distance_from_football(off_df, ball_df)

# %% [markdown]
# After we've separated the data between offense and defense, we can create separate models for them.

# %%
# Train defensive model
def_model, def_scaler_X, def_scaler_y, def_history = train_improved_route_predictor(
    def_df_with_distance,
    side='defense'
)

# Train offensive model
off_model, off_scaler_X, off_scaler_y, off_history = train_improved_route_predictor(
    off_df_with_distance,
    side='offense'
)
# Out:
# Preparing sequences for training...
# Adding missing formation column: formation_UNDER_CENTER
# Adding missing formation column: formation_NO_HUDDLE_SHOTGUN
# Adding missing formation column: formation_NO_HUDDLE
# 100%|██████████| 78017/78017 [01:14<00:00, 1046.75it/s]
# Epoch 1/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - loss: 0.1931 - val_loss: 0.0209 - learning_rate: 0.0010
# Epoch 2/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0603 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 3/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0535 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 4/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0522 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 5/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0485 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 6/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0485 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 7/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0478 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 8/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0482 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 9/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0474 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 10/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0456 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 11/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0466 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 12/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0445 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 13/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0457 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 14/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 48s 24ms/step - loss: 0.0460 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 15/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0441 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 16/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0452 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 17/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0435 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 18/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0410 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 19/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0407 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 20/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0410 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 21/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0426 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0405 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 23/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0413 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 24/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0412 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 25/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - loss: 0.0420 - val_loss: 0.0039 - learning_rate: 5.0000e-04
# Epoch 26/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0399 - val_loss: 0.0037 - learning_rate: 5.0000e-04
# Epoch 27/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0424 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 28/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0423 - val_loss: 0.0041 - learning_rate: 5.0000e-04
# Epoch 29/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0412 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 30/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0417 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 31/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0390 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 32/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0395 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 33/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0409 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 34/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0396 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 35/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0411 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 36/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0403 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 37/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0395 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 38/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0405 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 39/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0394 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 40/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0396 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 41/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0401 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 42/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0387 - val_loss: 0.0038 - learning_rate: 1.2500e-04
# Epoch 43/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0398 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 44/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - loss: 0.0386 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 45/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0384 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 46/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0422 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 47/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0390 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 48/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0402 - val_loss: 0.0034 - learning_rate: 1.2500e-04
# Epoch 49/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0396 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 50/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0390 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 51/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 38s 19ms/step - loss: 0.0401 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 52/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0385 - val_loss: 0.0030 - learning_rate: 6.2500e-05
# Epoch 53/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 36s 19ms/step - loss: 0.0400 - val_loss: 0.0030 - learning_rate: 6.2500e-05
# Epoch 54/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0401 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 55/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0380 - val_loss: 0.0031 - learning_rate: 6.2500e-05
# Epoch 56/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 37s 19ms/step - loss: 0.0402 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 57/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - loss: 0.0383 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 58/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - loss: 0.0397 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 59/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - loss: 0.0390 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 60/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - loss: 0.0396 - val_loss: 0.0035 - learning_rate: 3.1250e-05
# Epoch 61/150
# 1947/1947 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - loss: 0.0392 - val_loss: 0.0036 - learning_rate: 3.1250e-05
# Preparing sequences for training...
# Adding missing formation column: formation_UNDER_CENTER
# Adding missing formation column: formation_NO_HUDDLE_SHOTGUN
# Adding missing formation column: formation_NO_HUDDLE
# 100%|██████████| 47861/47861 [00:46<00:00, 1030.50it/s]
# Epoch 1/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.5051 - val_loss: 0.0286 - learning_rate: 0.0010
# Epoch 2/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0734 - val_loss: 0.0185 - learning_rate: 0.0010
# Epoch 3/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0605 - val_loss: 0.0148 - learning_rate: 0.0010
# Epoch 4/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0578 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 5/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - loss: 0.0546 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 6/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0521 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 7/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0494 - val_loss: 0.0215 - learning_rate: 0.0010
# Epoch 8/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0515 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 9/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0490 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 10/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0482 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 11/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0480 - val_loss: 0.0147 - learning_rate: 0.0010
# Epoch 12/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0484 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 13/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0459 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 14/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0517 - val_loss: 0.0198 - learning_rate: 0.0010
# Epoch 15/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0490 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 16/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0435 - val_loss: 0.2637 - learning_rate: 0.0010
# Epoch 17/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0422 - val_loss: 0.3151 - learning_rate: 5.0000e-04
# Epoch 18/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0430 - val_loss: 0.2033 - learning_rate: 5.0000e-04
# Epoch 19/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0413 - val_loss: 0.0459 - learning_rate: 5.0000e-04
# Epoch 20/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0400 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 21/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0400 - val_loss: 0.0273 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0399 - val_loss: 0.0338 - learning_rate: 5.0000e-04
# Epoch 23/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0418 - val_loss: 0.2125 - learning_rate: 5.0000e-04
# Epoch 24/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0400 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 25/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0410 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 26/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0400 - val_loss: 0.0433 - learning_rate: 5.0000e-04
# Epoch 27/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0402 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 28/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0378 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 29/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0367 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 30/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0386 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 31/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0402 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 32/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0375 - val_loss: 0.0036 - learning_rate: 2.5000e-04
# Epoch 33/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0382 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 34/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0363 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 35/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0373 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 36/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0402 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 37/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0388 - val_loss: 0.0037 - learning_rate: 2.5000e-04
# Epoch 38/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0385 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 39/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0377 - val_loss: 0.0035 - learning_rate: 2.5000e-04
# Epoch 40/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0374 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 41/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0370 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 42/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0353 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 43/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0378 - val_loss: 0.0042 - learning_rate: 2.5000e-04
# Epoch 44/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0358 - val_loss: 0.0050 - learning_rate: 2.5000e-04
# Epoch 45/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0371 - val_loss: 0.0035 - learning_rate: 2.5000e-04
# Epoch 46/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0374 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 47/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0371 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 48/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0378 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 49/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0373 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 50/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0368 - val_loss: 0.0034 - learning_rate: 1.2500e-04
# Epoch 51/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0352 - val_loss: 0.0043 - learning_rate: 1.2500e-04
# Epoch 52/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0366 - val_loss: 0.0043 - learning_rate: 1.2500e-04
# Epoch 53/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0367 - val_loss: 0.0041 - learning_rate: 1.2500e-04
# Epoch 54/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0369 - val_loss: 0.0039 - learning_rate: 1.2500e-04
# Epoch 55/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0356 - val_loss: 0.0044 - learning_rate: 1.2500e-04
# Epoch 56/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0332 - val_loss: 0.0043 - learning_rate: 1.2500e-04
# Epoch 57/150
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0368 - val_loss: 0.0036 - learning_rate: 6.2500e-05

# %% [markdown]
# Then, we save the model and download it to your local computer. From there, I was able to upload the model to GitHub to load in a separate Colab file.

# %%
# Save
save_models_and_scalers(
    'offensive',
    off_model,
    off_scaler_X,
    off_scaler_y,
    off_history
)

save_models_and_scalers(
    'defensive',
    def_model,
    def_scaler_X,
    def_scaler_y,
    def_history
)

# %% [markdown]
# With the model, we can look at its predictions vs the actual routes that occurred. The validation loss is reasonable, while the model appears to capture future player routes relatively well.

# %%
# Analyze a specific play
game_id = 2022100908
play_id = 3635

# Get defensive predictions
def_predictions, def_routes = analyze_specific_play_by_side(
    def_df_with_distance,
    def_model,
    def_scaler_X,
    def_scaler_y,
    game_id,
    play_id,
    side='defense'
)

# Get offensive predictions
off_predictions, off_routes = analyze_specific_play_by_side(
    off_df_with_distance,
    off_model,
    off_scaler_X,
    off_scaler_y,
    game_id,
    play_id,
    side='offense'
)

# %% [markdown]
# Finally, we can take a look at the overlap of offense and defense location predictions.

# %%
# Get overlap visualization and metrics
overlap_metrics = plot_route_overlap(
    initial_positions_off=off_df_with_distance.filter(
        (pl.col('gameId') == game_id) &
        (pl.col('playId') == play_id)
    ).group_by('nflId').first().to_pandas(),
    initial_positions_def=def_df_with_distance.filter(
        (pl.col('gameId') == game_id) &
        (pl.col('playId') == play_id)
    ).group_by('nflId').first().to_pandas(),
    off_predictions=off_predictions,
    def_predictions=def_predictions,
    off_routes=off_routes,
    def_routes=def_routes,
    game_id=game_id,
    play_id=play_id
)
